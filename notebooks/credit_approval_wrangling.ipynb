# %% [markdown]
# # **Data Loading**

# %%
from google.colab import drive
import os
import zipfile

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
# Mount Google Drive to access kaggle.json
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Copy kaggle.json from Google Drive
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/Kaggle/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download the dataset
# !kaggle datasets download -d rikdifos/credit-card-approval-prediction

# Unzip it
with zipfile.ZipFile("credit-card-approval-prediction.zip", "r") as zip_ref:
    zip_ref.extractall("credit_data")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rikdifos/credit-card-approval-prediction
# License(s): CC0-1.0
# Downloading credit-card-approval-prediction.zip to /content
#   0% 0.00/5.32M [00:00<?, ?B/s]
# 100% 5.32M/5.32M [00:00<00:00, 514MB/s]

# %%
# Load the application and credit data
app_raw = pd.read_csv("credit_data/application_record.csv")
cred_raw = pd.read_csv("credit_data/credit_record.csv")

# %% [markdown]
# # **Data Exploration**

# %%
app_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
#  15  FLAG_EMAIL           438557 non-null  int64
#  16  OCCUPATION_TYPE      304354 non-null  object
#  17  CNT_FAM_MEMBERS      438557 non-null  float64
# dtypes: float64(2), int64(8), object(8)
# memory usage: 60.2+ MB

# %%
app_raw.sample()
# Out:
#            ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 3455  5022815           F            N               Y             0
#
#       AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 3455          261000.0  Commercial associate  Secondary / secondary special
#
#         NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 3455  Single / not married  House / apartment       -8477           -947
#
#       FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 3455           1                0           1           1        Laborers
#
#       CNT_FAM_MEMBERS
# 3455              1.0

# %%
app_raw['ID'].duplicated().any()
# Out:
# np.True_

# %%
app_raw[app_raw['ID'].duplicated(keep=False)].sort_values('ID')
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 425023  7022197           F            N               Y             0
# 426818  7022197           M            Y               Y             3
# 431911  7022327           M            Y               Y             0
# 431545  7022327           F            N               Y             0
# 425486  7023108           M            Y               Y             1
# ...         ...         ...          ...             ...           ...
# 426563  7836711           F            N               Y             2
# 428620  7836971           F            N               Y             0
# 421464  7836971           M            Y               N             1
# 422068  7838075           M            N               Y             0
# 423702  7838075           F            Y               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 425023          450000.0  Commercial associate               Higher education
# 426818          135000.0               Working  Secondary / secondary special
# 431911          256500.0  Commercial associate               Higher education
# 431545          135000.0  Commercial associate  Secondary / secondary special
# 425486           67500.0               Working  Secondary / secondary special
# ...                  ...                   ...                            ...
# 426563          292500.0               Working               Higher education
# 428620          103500.0               Working  Secondary / secondary special
# 421464          157500.0               Working  Secondary / secondary special
# 422068          337500.0  Commercial associate  Secondary / secondary special
# 423702          315000.0  Commercial associate               Higher education
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 425023             Separated  House / apartment      -19813          -1799
# 426818               Married  House / apartment      -11945           -735
# 431911               Married  House / apartment      -21503          -1674
# 431545  Single / not married  House / apartment      -14771          -5298
# 425486               Married  House / apartment      -15156          -1696
# ...                      ...                ...         ...            ...
# 426563               Married  House / apartment      -13747          -4386
# 428620        Civil marriage  House / apartment      -13383          -2798
# 421464               Married  House / apartment      -13771          -5520
# 422068               Married  House / apartment      -18198          -1275
# 423702  Single / not married  House / apartment      -10698          -1659
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# 425023           1                0           0           1
# 426818           1                0           0           1
# 431911           1                0           0           1
# 431545           1                0           0           0
# 425486           1                1           0           0
# ...            ...              ...         ...         ...
# 426563           1                0           1           0
# 428620           1                0           1           0
# 421464           1                0           0           0
# 422068           1                0           0           1
# 423702           1                0           0           1
#
#               OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 425023                    NaN              1.0
# 426818               Laborers              5.0
# 431911             Core staff              2.0
# 431545  High skill tech staff              1.0
# 425486             Core staff              3.0
# ...                       ...              ...
# 426563            Accountants              4.0
# 428620            Sales staff              2.0
# 421464                    NaN              3.0
# 422068                Drivers              2.0
# 423702                    NaN              1.0
#
# [94 rows x 18 columns]

# %%
app_raw.isna().values.any()
# Out:
# np.True_

# %%
app_raw.isna().mean()[app_raw.isna().any()] * 100
# Out:
# OCCUPATION_TYPE    30.601039
# dtype: float64

# %%
cred_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   ID              1048575 non-null  int64
#  1   MONTHS_BALANCE  1048575 non-null  int64
#  2   STATUS          1048575 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %%
cred_raw.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
cred_raw['ID'].nunique()
# Out:
# 45985

# %%
cred_raw['STATUS'].value_counts(normalize=True, dropna=False) * 100
# Out:
# STATUS
# C    42.155401
# 0    36.537205
# X    19.953747
# 1     1.057626
# 5     0.161457
# 2     0.082779
# 3     0.030518
# 4     0.021267
# Name: proportion, dtype: float64

# %%
cred_raw.isna().values.any()
# Out:
# np.False_

# %% [markdown]
# # **Data Reduction || Labeling, Converting & Aggregating**

# %% [markdown]
# ## FLAG_OVERDUE_30D

# %%
cred_prep = cred_raw.copy()
cred_prep['FLAG_OVERDUE_30D'] = cred_prep['STATUS'].isin(['1', '2', '3', '4', '5']).astype(int)
cred_prep[['STATUS', 'FLAG_OVERDUE_30D']].sample(5)
# Out:
#        STATUS  FLAG_OVERDUE_30D
# 824973      C                 0
# 715533      X                 0
# 774173      0                 0
# 584465      0                 0
# 34969       C                 0

# %%
cred_prep['FLAG_OVERDUE_30D'].value_counts(normalize=True) * 100
# Out:
# FLAG_OVERDUE_30D
# 0    98.646353
# 1     1.353647
# Name: proportion, dtype: float64

# %% [markdown]
# ## MONTHS_RECORD

# %%
cred_prep['MONTHS_RECORD'] = cred_prep['MONTHS_BALANCE'].abs()
cred_prep[['MONTHS_BALANCE', 'MONTHS_RECORD']].head()
# Out:
#    MONTHS_BALANCE  MONTHS_RECORD
# 0               0              0
# 1              -1              1
# 2              -2              2
# 3              -3              3
# 4               0              0

# %%
cred_prep.columns.tolist()
# Out:
# ['ID', 'MONTHS_BALANCE', 'STATUS', 'FLAG_OVERDUE_30D', 'MONTHS_RECORD']

# %%
cred_prep = cred_prep.groupby('ID')[['MONTHS_RECORD', 'FLAG_OVERDUE_30D']].max().reset_index()
cred_prep
# Out:
#             ID  MONTHS_RECORD  FLAG_OVERDUE_30D
# 0      5001711              3                 0
# 1      5001712             18                 0
# 2      5001713             21                 0
# 3      5001714             14                 0
# 4      5001715             59                 0
# ...        ...            ...               ...
# 45980  5150482             28                 0
# 45981  5150483             17                 0
# 45982  5150484             12                 0
# 45983  5150485              1                 0
# 45984  5150487             29                 0
#
# [45985 rows x 3 columns]

# %% [markdown]
# # **Data Blending**

# %%
app_raw.loc[app_raw['ID'].duplicated(), 'ID'].isin(cred_prep['ID']).any()
# Out:
# np.False_

# %%
cred_prep['ID'].duplicated().any()
# Out:
# np.False_

# %%
merged_df = pd.merge(app_raw, cred_prep, on='ID', how='inner')
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36457 entries, 0 to 36456
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   36457 non-null  int64
#  1   CODE_GENDER          36457 non-null  object
#  2   FLAG_OWN_CAR         36457 non-null  object
#  3   FLAG_OWN_REALTY      36457 non-null  object
#  4   CNT_CHILDREN         36457 non-null  int64
#  5   AMT_INCOME_TOTAL     36457 non-null  float64
#  6   NAME_INCOME_TYPE     36457 non-null  object
#  7   NAME_EDUCATION_TYPE  36457 non-null  object
#  8   NAME_FAMILY_STATUS   36457 non-null  object
#  9   NAME_HOUSING_TYPE    36457 non-null  object
#  10  DAYS_BIRTH           36457 non-null  int64
#  11  DAYS_EMPLOYED        36457 non-null  int64
#  12  FLAG_MOBIL           36457 non-null  int64
#  13  FLAG_WORK_PHONE      36457 non-null  int64
#  14  FLAG_PHONE           36457 non-null  int64
#  15  FLAG_EMAIL           36457 non-null  int64
#  16  OCCUPATION_TYPE      25134 non-null  object
#  17  CNT_FAM_MEMBERS      36457 non-null  float64
#  18  MONTHS_RECORD        36457 non-null  int64
#  19  FLAG_OVERDUE_30D     36457 non-null  int64
# dtypes: float64(2), int64(10), object(8)
# memory usage: 5.6+ MB

# %% [markdown]
# # **Data Cleansing || Dropping, Converting & Fixing**

# %%
prep_df = merged_df.copy()
prep_df.sample()
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 28694  5116536           F            N               N             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 28694          135000.0  Commercial associate  Secondary / secondary special
#
#       NAME_FAMILY_STATUS    NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 28694            Married  Municipal apartment      -18524          -1707
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 28694           1                0           0           0             NaN
#
#        CNT_FAM_MEMBERS  MONTHS_RECORD  FLAG_OVERDUE_30D
# 28694              2.0             33                 1

# %%
prep_df.drop(columns='ID').select_dtypes(include='number').nunique()
# Out:
# CNT_CHILDREN           9
# AMT_INCOME_TOTAL     265
# DAYS_BIRTH          7183
# DAYS_EMPLOYED       3640
# FLAG_MOBIL             1
# FLAG_WORK_PHONE        2
# FLAG_PHONE             2
# FLAG_EMAIL             2
# CNT_FAM_MEMBERS       10
# MONTHS_RECORD         61
# FLAG_OVERDUE_30D       2
# dtype: int64

# %% [markdown]
# ## DAYS_BIRTH

# %%
prep_df[prep_df['DAYS_BIRTH'] == 0].values.any()
# Out:
# np.False_

# %%
prep_df['DAYS_BIRTH'].head()
# Out:
# 0   -12005
# 1   -12005
# 2   -21474
# 3   -19110
# 4   -19110
# Name: DAYS_BIRTH, dtype: int64

# %%
prep_df['DAYS_BIRTH'] = prep_df['DAYS_BIRTH'].abs()
prep_df['DAYS_BIRTH'].head()
# Out:
# 0    12005
# 1    12005
# 2    21474
# 3    19110
# 4    19110
# Name: DAYS_BIRTH, dtype: int64

# %% [markdown]
# ## FLAG_MOBIL

# %%
prep_df['FLAG_MOBIL'].value_counts(normalize=True) * 100
# Out:
# FLAG_MOBIL
# 1    100.0
# Name: proportion, dtype: float64

# %%
prep_df.drop('FLAG_MOBIL', axis=1, inplace=True)
prep_df.shape
# Out:
# (36457, 19)

# %%
prep_df.drop(columns='ID').select_dtypes(include='number').describe().T
# Out:
#                     count           mean            std      min       25%  \
# CNT_CHILDREN      36457.0       0.430315       0.742367      0.0       0.0
# AMT_INCOME_TOTAL  36457.0  186685.736662  101789.226482  27000.0  121500.0
# DAYS_BIRTH        36457.0   15975.173382    4200.549944   7489.0   12462.0
# DAYS_EMPLOYED     36457.0   59262.935568  137651.334859 -15713.0   -3153.0
# FLAG_WORK_PHONE   36457.0       0.225526       0.417934      0.0       0.0
# FLAG_PHONE        36457.0       0.294813       0.455965      0.0       0.0
# FLAG_EMAIL        36457.0       0.089722       0.285787      0.0       0.0
# CNT_FAM_MEMBERS   36457.0       2.198453       0.911686      1.0       2.0
# MONTHS_RECORD     36457.0      26.164193      16.501854      0.0      12.0
# FLAG_OVERDUE_30D  36457.0       0.117700       0.322257      0.0       0.0
#
#                        50%       75%        max
# CNT_CHILDREN           0.0       1.0       19.0
# AMT_INCOME_TOTAL  157500.0  225000.0  1575000.0
# DAYS_BIRTH         15563.0   19438.0    25152.0
# DAYS_EMPLOYED      -1552.0    -408.0   365243.0
# FLAG_WORK_PHONE        0.0       0.0        1.0
# FLAG_PHONE             0.0       1.0        1.0
# FLAG_EMAIL             0.0       0.0        1.0
# CNT_FAM_MEMBERS        2.0       3.0       20.0
# MONTHS_RECORD         24.0      39.0       60.0
# FLAG_OVERDUE_30D       0.0       0.0        1.0

# %% [markdown]
# ## DAYS_EMPLOYED

# %%
prep_df['DAYS_EMPLOYED'].dtype
# Out:
# dtype('int64')

# %%
prep_df[prep_df['DAYS_EMPLOYED'] == 0].values.any()
# Out:
# np.False_

# %%
print(f"Count of unique values < 0: {prep_df[prep_df['DAYS_EMPLOYED'] < 0]['DAYS_EMPLOYED'].nunique()}")
print(f"Count of unique values > 0: {prep_df[prep_df['DAYS_EMPLOYED'] > 0]['DAYS_EMPLOYED'].nunique()}")
# Out:
# Count of unique values < 0: 3639
# Count of unique values > 0: 1

# %%
prep_df[prep_df['DAYS_EMPLOYED'] > 0]['DAYS_EMPLOYED'].unique()
# Out:
# array([365243])

# %%
prep_df['DAYS_EMPLOYED'] = prep_df['DAYS_EMPLOYED'].replace(365243, 0)
prep_df['DAYS_EMPLOYED'] = prep_df['DAYS_EMPLOYED'].abs().astype(int)

print(f"Count of unique values = 0: {prep_df[prep_df['DAYS_EMPLOYED'] == 0]['DAYS_EMPLOYED'].nunique()}")
print(f"Count of unique values > 0: {prep_df[prep_df['DAYS_EMPLOYED'] > 0]['DAYS_EMPLOYED'].nunique()}")
# Out:
# Count of unique values = 0: 1
# Count of unique values > 0: 3639

# %%
print(f"Count of values = 0: {len(prep_df[prep_df['DAYS_EMPLOYED'] == 0])}")
print(f"Count of values > 0: {len(prep_df[prep_df['DAYS_EMPLOYED'] > 0])}")
print(f"Total count: {len(prep_df[prep_df['DAYS_EMPLOYED'] >= 0])}")
# Out:
# Count of values = 0: 6135
# Count of values > 0: 30322
# Total count: 36457

# %%
prep_df.select_dtypes(include='object').nunique()
# Out:
# CODE_GENDER             2
# FLAG_OWN_CAR            2
# FLAG_OWN_REALTY         2
# NAME_INCOME_TYPE        5
# NAME_EDUCATION_TYPE     5
# NAME_FAMILY_STATUS      5
# NAME_HOUSING_TYPE       6
# OCCUPATION_TYPE        18
# dtype: int64

# %% [markdown]
# ## CODE_GENDER

# %%
prep_df['CODE_GENDER'].value_counts(normalize=True) * 100
# Out:
# CODE_GENDER
# F    67.010451
# M    32.989549
# Name: proportion, dtype: float64

# %%
prep_df['FLAG_GENDER'] = prep_df['CODE_GENDER'].map({'F': 0, 'M': 1})
prep_df.drop('CODE_GENDER', axis=1, inplace=True)
prep_df['FLAG_GENDER'].value_counts(normalize=True) * 100
# Out:
# FLAG_GENDER
# 0    67.010451
# 1    32.989549
# Name: proportion, dtype: float64

# %% [markdown]
# ## FLAG_CAR

# %%
prep_df['FLAG_OWN_CAR'].value_counts(normalize=True) * 100
# Out:
# FLAG_OWN_CAR
# N    62.02924
# Y    37.97076
# Name: proportion, dtype: float64

# %%
prep_df['FLAG_CAR'] = prep_df['FLAG_OWN_CAR'].map({'N': 0, 'Y': 1})
prep_df.drop('FLAG_OWN_CAR', axis=1, inplace=True)
prep_df['FLAG_CAR'].value_counts(normalize=True) * 100
# Out:
# FLAG_CAR
# 0    62.02924
# 1    37.97076
# Name: proportion, dtype: float64

# %% [markdown]
# ## FLAG_REALTY

# %%
prep_df['FLAG_OWN_REALTY'].value_counts(normalize=True) * 100
# Out:
# FLAG_OWN_REALTY
# Y    67.218915
# N    32.781085
# Name: proportion, dtype: float64

# %%
prep_df['FLAG_REALTY'] = prep_df['FLAG_OWN_REALTY'].map({'N': 0, 'Y': 1})
prep_df.drop('FLAG_OWN_REALTY', axis=1, inplace=True)
prep_df['FLAG_REALTY'].value_counts(normalize=True) * 100
# Out:
# FLAG_REALTY
# 1    67.218915
# 0    32.781085
# Name: proportion, dtype: float64

# %% [markdown]
# ## OCCUPATION_TYPE

# %%
prep_df['OCCUPATION_TYPE'].unique()
# Out:
# array([nan, 'Security staff', 'Sales staff', 'Accountants', 'Laborers',
#        'Managers', 'Drivers', 'Core staff', 'High skill tech staff',
#        'Cleaning staff', 'Private service staff', 'Cooking staff',
#        'Low-skill Laborers', 'Medicine staff', 'Secretaries',
#        'Waiters/barmen staff', 'HR staff', 'Realty agents', 'IT staff'],
#       dtype=object)

# %%
prep_df['OCCUPATION_TYPE'].isna().sum() / len(prep_df) * 100
# Out:
# np.float64(31.05850728255205)

# %%
prep_df.drop('OCCUPATION_TYPE', axis=1, inplace=True)
prep_df.shape
# Out:
# (36457, 18)

# %% [markdown]
# # **Data Validation || Filtering, Winsorizing & Detecting**

# %% [markdown]
# ## Checking Cardinality

# %%
for col in prep_df.select_dtypes(include='object').columns.tolist():
    print(prep_df[col].value_counts(normalize=True) * 100)
    print()
# Out:
# NAME_INCOME_TYPE
# Working                 51.619716
# Commercial associate    23.287709
# Pensioner               16.874674
# State servant            8.187728
# Student                  0.030173
# Name: proportion, dtype: float64
#
# NAME_EDUCATION_TYPE
# Secondary / secondary special    67.962257
# Higher education                 27.056532
# Incomplete higher                 3.867570
# Lower secondary                   1.025866
# Academic degree                   0.087775
# Name: proportion, dtype: float64
#
# NAME_FAMILY_STATUS
# Married                 68.705598
# Single / not married    13.245742
# Civil marriage           8.078010
# Separated                5.768440
# Widow                    4.202211
# Name: proportion, dtype: float64
#
# NAME_HOUSING_TYPE
# House / apartment      89.277779
# With parents            4.871492
# Municipal apartment     3.094056
# Rented apartment        1.577201
# Office apartment        0.718655
# Co-op apartment         0.460817
# Name: proportion, dtype: float64

# %%
housing_realty = (
    prep_df
    .groupby('NAME_HOUSING_TYPE')['FLAG_REALTY']
    .value_counts(normalize=True)
    .mul(100)
    .unstack()
)
housing_realty
# Out:
# FLAG_REALTY                  0          1
# NAME_HOUSING_TYPE
# Co-op apartment      35.714286  64.285714
# House / apartment    29.565565  70.434435
# Municipal apartment  63.829787  36.170213
# Office apartment     58.778626  41.221374
# Rented apartment     42.608696  57.391304
# With parents         64.695946  35.304054

# %%
prep_df.drop(columns='ID').select_dtypes(include='number').describe().T
# Out:
#                     count           mean            std      min       25%  \
# CNT_CHILDREN      36457.0       0.430315       0.742367      0.0       0.0
# AMT_INCOME_TOTAL  36457.0  186685.736662  101789.226482  27000.0  121500.0
# DAYS_BIRTH        36457.0   15975.173382    4200.549944   7489.0   12462.0
# DAYS_EMPLOYED     36457.0    2200.317168    2366.796762      0.0     408.0
# FLAG_WORK_PHONE   36457.0       0.225526       0.417934      0.0       0.0
# FLAG_PHONE        36457.0       0.294813       0.455965      0.0       0.0
# FLAG_EMAIL        36457.0       0.089722       0.285787      0.0       0.0
# CNT_FAM_MEMBERS   36457.0       2.198453       0.911686      1.0       2.0
# MONTHS_RECORD     36457.0      26.164193      16.501854      0.0      12.0
# FLAG_OVERDUE_30D  36457.0       0.117700       0.322257      0.0       0.0
# FLAG_GENDER       36457.0       0.329895       0.470181      0.0       0.0
# FLAG_CAR          36457.0       0.379708       0.485321      0.0       0.0
# FLAG_REALTY       36457.0       0.672189       0.469422      0.0       0.0
#
#                        50%       75%        max
# CNT_CHILDREN           0.0       1.0       19.0
# AMT_INCOME_TOTAL  157500.0  225000.0  1575000.0
# DAYS_BIRTH         15563.0   19438.0    25152.0
# DAYS_EMPLOYED       1552.0    3153.0    15713.0
# FLAG_WORK_PHONE        0.0       0.0        1.0
# FLAG_PHONE             0.0       1.0        1.0
# FLAG_EMAIL             0.0       0.0        1.0
# CNT_FAM_MEMBERS        2.0       3.0       20.0
# MONTHS_RECORD         24.0      39.0       60.0
# FLAG_OVERDUE_30D       0.0       0.0        1.0
# FLAG_GENDER            0.0       1.0        1.0
# FLAG_CAR               0.0       1.0        1.0
# FLAG_REALTY            1.0       1.0        1.0

# %% [markdown]
# ## Handling Outliers

# %%
# Shared variables
flag_cols = ['FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'FLAG_OVERDUE_30D',
             'FLAG_GENDER', 'FLAG_CAR', 'FLAG_REALTY']
outlier_cols = ['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'CNT_FAM_MEMBERS']

# Remaining numeric columns
numeric_cols = prep_df.drop(columns='ID').select_dtypes(include='number').columns.tolist()
remaining_cols = []
for col in numeric_cols:
    if col not in flag_cols:
        remaining_cols.append(col)

# Formatter to display thousands with 'k' (but not on 0)
def format_k(x, pos):
    if x == 0:
        return '0'
    if abs(x) >= 1000:
        return str(int(x / 1000)) + 'k'
    return str(int(x))

# %%
# Set grid size
fig, axes = plt.subplots(2, 4, figsize=(12, 4))  # 2x4 for 7 flags, 8 slots total
axes = axes.flatten()

# Plot each flag column
for i in range(len(flag_cols)):
    col = flag_cols[i]
    ax = axes[i]
    sns.scatterplot(x=prep_df.index, y=prep_df[col], ax=ax, alpha=0.4)
    ax.set_xlabel("Index")
    ax.set_ylabel(col)
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))  # Show integers only

# Hide unused axes
for j in range(len(flag_cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# Set grid size
fig, axes = plt.subplots(3, 3, figsize=(12, 6))  # 3x3 fixed layout
axes = axes.flatten()

# Plot each remaining numeric column
for i in range(len(remaining_cols)):
    col = remaining_cols[i]
    ax = axes[i]
    color = 'red' if col in outlier_cols else None

    sns.scatterplot(x=prep_df.index, y=prep_df[col], ax=ax, alpha=0.4, color=color)
    ax.set_xlabel("Index")
    ax.set_ylabel(col)
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(format_k))

# Hide unused axes
for j in range(len(remaining_cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
prep_df['CNT_CHILDREN'] = prep_df['CNT_CHILDREN'].clip(upper=5)
prep_df['AMT_INCOME_TOTAL'] = prep_df['AMT_INCOME_TOTAL'].clip(upper=1_000_000)
prep_df['CNT_FAM_MEMBERS'] = prep_df['CNT_FAM_MEMBERS'].clip(upper=7)

# %%
# Set grid size
fig, axes = plt.subplots(3, 3, figsize=(12, 6))  # 3x3 fixed layout
axes = axes.flatten()

# Plot each remaining numeric column
for i in range(len(remaining_cols)):
    col = remaining_cols[i]
    ax = axes[i]

    sns.scatterplot(x=prep_df.index, y=prep_df[col], ax=ax, alpha=0.4, color=color)
    ax.set_xlabel("Index")
    ax.set_ylabel(col)
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(format_k))

# Hide unused axes
for j in range(len(remaining_cols), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Detecting Multicollinearity

# %%
prep_df.drop(columns='ID').select_dtypes(include='number').sample()
# Out:
#        CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 33095             0           90000.0       14046           1306
#
#        FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  \
# 33095                1           1           0              2.0
#
#        MONTHS_RECORD  FLAG_OVERDUE_30D  FLAG_GENDER  FLAG_CAR  FLAG_REALTY
# 33095             13                 0            0         0            0

# %%
# Visualize correlation matrix
plt.figure(figsize=(14, 10))
sns.heatmap(
    prep_df.corr(numeric_only=True),
    annot=True,
    fmt=".1f"
)
plt.xticks(rotation=45)
plt.show()

# %%
# Identify multicollinearity
corr_matrix = prep_df.corr(numeric_only=True).abs()
upper_corr = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
high_corr_cols = [col for col in upper_corr.columns.tolist() if any(upper_corr[col] > 0.7)]
high_corr_cols
# Out:
# ['CNT_FAM_MEMBERS']

# %%
prepared_df = prep_df.copy()
prepared_df = prepared_df.sort_values(by='ID')

# Export to CSV
filename = 'credit_data_prepared_pandas.csv'
prepared_df.to_csv(filename, index=False)

print("File saved at:", os.path.abspath(filename))
# Out:
# File saved at: /content/credit_data_prepared_pandas.csv
